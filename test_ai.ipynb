# %%
import numpy as np
import pandas as pd 
import matplotlib
import sklearn
print("Numpy",np.__version__)
print("Pandas",pd.__version__)
print("Matplotlib",matplotlib.__version__)
print("Scikit-learn",sklearn.__version__)
print("AI environment is working!")
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/sai keerthi/AppData/Local/Programs/Python/Python313/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
data=list(range(1,201))
train=data[:140]
validation=data[140:170]
test=data[170:]
print("Total:", len(data))
print("Training:", len(train))
print("Validation:", len(validation))
print("Testing:", len(test))

# %%
from sklearn.model_selection import train_test_split
data=list(range(1,201))
train, test = train_test_split(data, test_size=0.2,random_state=42)
print("Traininng:",len(train))
print("Testing:", len(test))

# %%
#linear regression
from sklearn.linear_model import LinearRegression
hours = [[1], [2], [3], [4], [5], [6]]
marks = [35, 42, 50, 58, 65, 72]
model=LinearRegression()
model.fit(hours,marks)
prediction=model.predict([[7]])
print("Predicted marks for 7 hours of study:", prediction[0])
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/sai keerthi/AppData/Local/Programs/Python/Python313/python.exe" -m pip install ipykernel -U --user --force-reinstall'
